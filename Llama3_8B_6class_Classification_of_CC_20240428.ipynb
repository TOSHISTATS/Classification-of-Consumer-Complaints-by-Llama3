# %% [markdown]
# # Classification_of_Consumer_Complaints by Llama3-8B 20240428

# %% [markdown]
# ## 1. ライブラリをインポート (Import library)

# %%
# !pip -q install langchain-groq duckduckgo-search
# !pip -q install -U langchain_community tiktoken langchainhub
# !pip -q install -U langchain langgraph tavily-python

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.1.16
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: aiohttp, async-timeout, dataclasses-json, jsonpatch, langchain-community, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
# !pip show langgraph
# Out:
# Name: langgraph
# Version: 0.0.39
# Summary: langgraph
# Home-page: https://www.github.com/langchain-ai/langgraph
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: langchain-core
# Required-by:

# %%
# !pip -q install langchain tiktoken  python-dotenv

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
os.environ["TAVILY_API_KEY"] = userdata.get('TAVILY_API_KEY')

# %%
### Tracing (optional)
import os
from pprint import pprint

# os.environ['LANGCHAIN TRACING V2'] = 'true'
# os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
# os.environ['LANGCHAIN API KEY'] = userdata.get('LANGCHAIN_API_KEY')

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.prompts import PromptTemplate

from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers import JsonOutputParser

# %% [markdown]
# ## 2. モデルをセット (Set the model throught API)

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama3-8b-8192",temperature=0)

# %%
#Categorize complaints
prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|>
    You are a Categorizer Agent You are a master at understanding what product do customers complaint of in the complaints? You can choose only one product.

     <|eot_id|><|start_header_id|>user<|end_header_id|>
    Conduct a comprehensive analysis of the complaints provided and categorize into one of the following categories:
        Mortgage\
        Checking or savings account \
        Student loan\
        Money transfer, virtual currency, or money service\
        Bank account or service\
        Consumer Loan\

            Output a single cetgory only from the types ( 'Mortgage', 'Checking or savings account', 'Student loan', 'Money transfer, virtual currency, or money service',\
       'Bank account or service', 'Consumer Loan'. Your answer should be one of the name of product in the list only. Do not include other words. \) \
            eg:
            'Mortgage' \

    EMAIL CONTENT:\n\n {email} \n\n
    <|eot_id|>
    <|start_header_id|>assistant<|end_header_id|>
    """,
    input_variables=["email"],
)

email_category_generator = prompt | model | StrOutputParser()

morg="Greetree ( changed name to Ditech servicing ) calls me all hours of the night. A representative name XXXX calls me. I told them that the only number the are allowed to contact me on is XXXX. My mother has said they also call on their number which is a separate line from my own line. Even after telling them this for months and years they still abuse this. As I have said before that the only line that I can be reach is on XXXX. I work from home and that is the only number that they can contact me regarding any information about the mortgage. I do n't know how clear I can be on discussing this with them regarding XXXX constant harassment. I am also considering legal action."

result = email_category_generator.invoke({"email": morg})

print(result)
# Out:
# Mortgage

# %%
morg
# Out:
# "Greetree ( changed name to Ditech servicing ) calls me all hours of the night. A representative name XXXX calls me. I told them that the only number the are allowed to contact me on is XXXX. My mother has said they also call on their number which is a separate line from my own line. Even after telling them this for months and years they still abuse this. As I have said before that the only line that I can be reach is on XXXX. I work from home and that is the only number that they can contact me regarding any information about the mortgage. I do n't know how clear I can be on discussing this with them regarding XXXX constant harassment. I am also considering legal action."

# %% [markdown]
# ## 3. dataをインポート (load data)

# %%
import time
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, classification_report

# %%
X=pd.read_csv("CC_20k_20230114.csv")
X
# Out:
#                             Product                                     Issue  \
# 0       Checking or savings account                       Managing an account
# 1       Checking or savings account                       Managing an account
# 2                          Mortgage            Trouble during payment process
# 3       Checking or savings account                       Managing an account
# 4                          Mortgage            Trouble during payment process
# ...                             ...                                       ...
# 199390      Bank account or service   Account opening, closing, or management
# 199391                 Student loan        Dealing with my lender or servicer
# 199392                     Mortgage  Loan modification,collection,foreclosure
# 199393                Consumer Loan                Managing the loan or lease
# 199394                     Mortgage  Loan modification,collection,foreclosure
#
#                                                      text  Complaint ID  \
# 0       XX/XX/2022. I began noticing charges to my deb...       6301154
# 1       I have a joint account with my Daughter. She g...       6280688
# 2       I made a principal payment of {$9900.00} on XX...       6257306
# 3       I created a Savings account XX/XX/2022 with Al...       6246992
# 4       Loan Number XXXX Reference : Mortgage XXXXXXXX...       6209018
# ...                                                   ...           ...
# 199390  Near the end of XXXX 2016 I opened a Citigold ...       2138969
# 199391  My loans have an extraordinarily high interest...       2302907
# 199392  Caliber Home Loans ( CHL ) sent confirmation i...       2302852
# 199393  On XX/XX/XXXX I purchased a XXXX XXXX XXXX XXX...       2282405
# 199394  My father died in XX/XX/XXXX. Left me his only...       1352738
#
#                                                        Ja
# 0       xx/xx/2022。私は自分のデビットカードへの料金とオンラインウェルズファーゴアカウント...
# 1       私は娘と共同アカウントを持っています。彼女はxxxx xxxxでxxxxに行き、私はxxxx...
# 2       xx/xx/22で{$ 9900.00}の主要な支払いを行いました。米国銀行は、XXXX X...
# 3       Ally Bankで普通預金口座XX/XX/2022を作成し、{$ 400.00}のデポジッ...
# 4       ローン番号xxxxリファレンス：Mortgage xxxxxxx xxxx xxxx xxx...
# ...                                                   ...
# 199390  XXXX 2016の終わり近くに、プロモーションコードXXXXでCitGold当座預金口座を...
# 199391             私のローンには非常に高い金利があり、私はそれらを借り換えることができません。
# 199392  キャリバーホームローン（CHL）は、2016年のXXXXで確認を送信し、ローンの変更が承認さ...
# 199393  xx/xx/xxxxでは、xxxx xxxx xxxx xxxxを購入しました。オハイオ州ド...
# 199394  父はxx/xx/xxxxで亡くなりました。私に彼の一人息子をすべて彼の持ち物に残しました、彼...
#
# [199395 rows x 5 columns]

# %%
X
# Out:
#                             Product                                     Issue  \
# 0       Checking or savings account                       Managing an account
# 1       Checking or savings account                       Managing an account
# 2                          Mortgage            Trouble during payment process
# 3       Checking or savings account                       Managing an account
# 4                          Mortgage            Trouble during payment process
# ...                             ...                                       ...
# 199390      Bank account or service   Account opening, closing, or management
# 199391                 Student loan        Dealing with my lender or servicer
# 199392                     Mortgage  Loan modification,collection,foreclosure
# 199393                Consumer Loan                Managing the loan or lease
# 199394                     Mortgage  Loan modification,collection,foreclosure
#
#                                                      text  Complaint ID  \
# 0       XX/XX/2022. I began noticing charges to my deb...       6301154
# 1       I have a joint account with my Daughter. She g...       6280688
# 2       I made a principal payment of {$9900.00} on XX...       6257306
# 3       I created a Savings account XX/XX/2022 with Al...       6246992
# 4       Loan Number XXXX Reference : Mortgage XXXXXXXX...       6209018
# ...                                                   ...           ...
# 199390  Near the end of XXXX 2016 I opened a Citigold ...       2138969
# 199391  My loans have an extraordinarily high interest...       2302907
# 199392  Caliber Home Loans ( CHL ) sent confirmation i...       2302852
# 199393  On XX/XX/XXXX I purchased a XXXX XXXX XXXX XXX...       2282405
# 199394  My father died in XX/XX/XXXX. Left me his only...       1352738
#
#                                                        Ja
# 0       xx/xx/2022。私は自分のデビットカードへの料金とオンラインウェルズファーゴアカウント...
# 1       私は娘と共同アカウントを持っています。彼女はxxxx xxxxでxxxxに行き、私はxxxx...
# 2       xx/xx/22で{$ 9900.00}の主要な支払いを行いました。米国銀行は、XXXX X...
# 3       Ally Bankで普通預金口座XX/XX/2022を作成し、{$ 400.00}のデポジッ...
# 4       ローン番号xxxxリファレンス：Mortgage xxxxxxx xxxx xxxx xxx...
# ...                                                   ...
# 199390  XXXX 2016の終わり近くに、プロモーションコードXXXXでCitGold当座預金口座を...
# 199391             私のローンには非常に高い金利があり、私はそれらを借り換えることができません。
# 199392  キャリバーホームローン（CHL）は、2016年のXXXXで確認を送信し、ローンの変更が承認さ...
# 199393  xx/xx/xxxxでは、xxxx xxxx xxxx xxxxを購入しました。オハイオ州ド...
# 199394  父はxx/xx/xxxxで亡くなりました。私に彼の一人息子をすべて彼の持ち物に残しました、彼...
#
# [199395 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
lab = lab.fit(X["Product"])
X["label"] = lab.transform(X["Product"])
X.head()
# Out:
#                        Product                           Issue  \
# 0  Checking or savings account             Managing an account
# 1  Checking or savings account             Managing an account
# 2                     Mortgage  Trouble during payment process
# 3  Checking or savings account             Managing an account
# 4                     Mortgage  Trouble during payment process
#
#                                                 text  Complaint ID  \
# 0  XX/XX/2022. I began noticing charges to my deb...       6301154
# 1  I have a joint account with my Daughter. She g...       6280688
# 2  I made a principal payment of {$9900.00} on XX...       6257306
# 3  I created a Savings account XX/XX/2022 with Al...       6246992
# 4  Loan Number XXXX Reference : Mortgage XXXXXXXX...       6209018
#
#                                                   Ja  label
# 0  xx/xx/2022。私は自分のデビットカードへの料金とオンラインウェルズファーゴアカウント...      1
# 1  私は娘と共同アカウントを持っています。彼女はxxxx xxxxでxxxxに行き、私はxxxx...      1
# 2  xx/xx/22で{$ 9900.00}の主要な支払いを行いました。米国銀行は、XXXX X...      4
# 3  Ally Bankで普通預金口座XX/XX/2022を作成し、{$ 400.00}のデポジッ...      1
# 4  ローン番号xxxxリファレンス：Mortgage xxxxxxx xxxx xxxx xxx...      4

# %%
Xp=X[0:5000]
Xp["Product"].value_counts()
# Out:
# Product
# Checking or savings account                           2000
# Mortgage                                              1660
# Student loan                                           628
# Money transfer, virtual currency, or money service     428
# Bank account or service                                192
# Consumer Loan                                           92
# Name: count, dtype: int64

# %%
X=X[5000:]

# %%
X["Product"].value_counts()
# Out:
# Product
# Mortgage                                              88101
# Checking or savings account                           52372
# Student loan                                          26787
# Money transfer, virtual currency, or money service    13184
# Bank account or service                                9546
# Consumer Loan                                          4405
# Name: count, dtype: int64

# %%
Xt=X[["text"]]
Xt
# Out:
#                                                      text
# 5000    In XXXX we applied for a line of credit with a...
# 5001    XX/XX/XXXX M & T bank called me and stated my ...
# 5002    On XX/XX/XXXX I purchased a watch online and p...
# 5003    Title is exactly as stated. \n\nTD Bank back i...
# 5004    I refinanced my loan with Wells Fargo. It was ...
# ...                                                   ...
# 199390  Near the end of XXXX 2016 I opened a Citigold ...
# 199391  My loans have an extraordinarily high interest...
# 199392  Caliber Home Loans ( CHL ) sent confirmation i...
# 199393  On XX/XX/XXXX I purchased a XXXX XXXX XXXX XXX...
# 199394  My father died in XX/XX/XXXX. Left me his only...
#
# [194395 rows x 1 columns]

# %%
yl=X[["label"]]
yl
# Out:
#         label
# 5000        2
# 5001        1
# 5002        3
# 5003        1
# 5004        4
# ...       ...
# 199390      0
# 199391      5
# 199392      4
# 199393      2
# 199394      4
#
# [194395 rows x 1 columns]

# %%
max(yl["label"])
# Out:
# 5

# %% [markdown]
# ## 4. 訓練データと検証データを作成　(Prepare training and test data)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(Xt, yl, stratify=yl, train_size=0.013, test_size=0.013, random_state=100)
len(X_train), len(y_train), len(X_valid), len(y_valid)
# Out:
# (2527, 2527, 2528, 2528)

# %%
X_valid
# Out:
#                                                      text
# 85871   I was recently sold from XXXX XXXX XXXX to set...
# 113030  2nd Mortgage Servicer Planet Home Lending Acc ...
# 57238   XXXX XXXX is an elderly women living in her ho...
# 130633  My mortgage got transferred to Nationstar Mort...
# 26169   OCWEN company has big problems communicating i...
# ...                                                   ...
# 159445  The reason for this complaint is that i believ...
# 157764  we are currently delinquent on our mortgage an...
# 25321   This is a follow up to three prior complaints ...
# 120677  Campus Partners, my loan servicer, has been co...
# 170167  On XX/XX/XXXX XXXX XXXX XXXX XXXX took {$1200....
#
# [2528 rows x 1 columns]

# %%
y_valid
# Out:
#         label
# 85871       4
# 113030      4
# 57238       4
# 130633      4
# 26169       4
# ...       ...
# 159445      5
# 157764      4
# 25321       4
# 120677      5
# 170167      1
#
# [2528 rows x 1 columns]

# %%
y_valid.nunique()
# Out:
# label    6
# dtype: int64

# %%
data = pd.concat([y_valid, X_valid], axis=1)
data
# Out:
#         label                                               text
# 85871       4  I was recently sold from XXXX XXXX XXXX to set...
# 113030      4  2nd Mortgage Servicer Planet Home Lending Acc ...
# 57238       4  XXXX XXXX is an elderly women living in her ho...
# 130633      4  My mortgage got transferred to Nationstar Mort...
# 26169       4  OCWEN company has big problems communicating i...
# ...       ...                                                ...
# 159445      5  The reason for this complaint is that i believ...
# 157764      4  we are currently delinquent on our mortgage an...
# 25321       4  This is a follow up to three prior complaints ...
# 120677      5  Campus Partners, my loan servicer, has been co...
# 170167      1  On XX/XX/XXXX XXXX XXXX XXXX XXXX took {$1200....
#
# [2528 rows x 2 columns]

# %% [markdown]
# ## 5. Llama3-8Bによりクレームを判別 (Classify customer complaints by Llama3-8B)

# %%
# %%time

result=[]
n=500
m=1000

for i in range(n,m):

  out = email_category_generator.invoke({"email": data.iloc[i,1]})
  result.append(out)

result
# Out:
# CPU times: user 13.5 s, sys: 1.13 s, total: 14.6 s
# Wall time: 20min 5s
# ['Student loan',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Consumer Loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Mortgage',
#  'Consumer Loan',
#  "'Student loan'",
#  'Mortgage',
#  'Checking or savings account',
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  "'Checking or savings account'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Bank account or service',
#  'Bank account or service',
#  'Student loan',
#  'Checking or savings account',
#  'Bank account or service',
#  'Checking or savings account',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  'Checking or savings account',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Student loan',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  "'Checking or savings account'",
#  'Checking or savings account',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Consumer Loan',
#  'Mortgage',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Checking or savings account',
#  'Bank account or service',
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  'Checking or savings account',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Checking or savings account',
#  'Student loan',
#  'Bank account or service',
#  'Checking or savings account',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Mortgage',
#  "'Mortgage'",
#  'Student loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Consumer Loan',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Money transfer, virtual currency, or money service',
#  'Checking or savings account',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  "'Bank account or service'",
#  'Mortgage',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Student loan',
#  'Bank account or service',
#  'Checking or savings account',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  "'Mortgage'",
#  "'Mortgage'",
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Bank account or service',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  "'Bank account or service'",
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Checking or savings account',
#  'Student loan',
#  'Mortgage',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Bank account or service',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Checking or savings account',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Checking or savings account',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Student loan',
#  "'Mortgage'",
#  'Mortgage',
#  'Checking or savings account',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Checking or savings account',
#  'Student loan',
#  'Consumer Loan',
#  'Bank account or service',
#  'Mortgage',
#  "'Student loan'",
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Student loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  "'Mortgage'",
#  'Mortgage',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Checking or savings account',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Checking or savings account',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Checking or savings account',
#  'Bank account or service',
#  'Checking or savings account',
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  'Consumer Loan',
#  'Student loan',
#  'Consumer Loan',
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  'Checking or savings account',
#  'Student loan',
#  'Checking or savings account',
#  'Student loan',
#  'Checking or savings account',
#  "'Mortgage'",
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Consumer Loan',
#  'Bank account or service',
#  "'Mortgage'",
#  'Bank account or service',
#  'Checking or savings account',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  "'Checking or savings account'",
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage']

# %%
range(n,m)
# Out:
# range(500, 1000)

# %%
s=result.copy()
for i in range(0,m-n):
    if "Bank account or service" in s[i]:
      s[i]=0
    elif "Checking or savings account" in s[i]:
      s[i]=1
    elif "Consumer Loan" in s[i]:
      s[i]=2
    elif "Money transfer, virtual currency, or money service" in s[i]:
      s[i]=3
    elif "Mortgage" in s[i]:
      s[i]=4
    elif "Student loan" in s[i]:
      s[i]=5
    else:
      s[i]=6
#s

# %% [markdown]
# ## 6. 精度検証　(Evaluate the model)

# %%
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x799596099840>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x79959609a0b0>, model_name='llama3-8b-8192', temperature=1e-08, groq_api_key=SecretStr('**********'))

# %%
label=list(y_valid['label'])[n:m]

print("result:", s)
print("label:", label)
# Out:
# result: [5, 4, 1, 2, 1, 1, 3, 1, 4, 2, 5, 4, 1, 1, 3, 0, 4, 5, 4, 5, 1, 3, 4, 4, 1, 5, 5, 4, 1, 4, 5, 4, 4, 1, 0, 0, 5, 1, 0, 1, 5, 4, 0, 1, 4, 1, 4, 0, 4, 0, 4, 0, 4, 4, 5, 4, 0, 4, 3, 3, 0, 4, 4, 4, 1, 1, 5, 0, 4, 4, 4, 1, 3, 0, 5, 3, 4, 5, 3, 4, 4, 4, 0, 4, 4, 5, 0, 4, 4, 4, 0, 2, 4, 5, 3, 0, 1, 0, 1, 3, 0, 4, 0, 4, 1, 5, 4, 4, 4, 4, 1, 4, 4, 4, 4, 1, 4, 4, 4, 0, 1, 4, 4, 4, 4, 5, 4, 4, 4, 5, 1, 4, 0, 4, 3, 3, 4, 5, 4, 4, 0, 4, 4, 5, 4, 4, 5, 0, 0, 4, 4, 4, 1, 3, 0, 4, 1, 4, 0, 4, 1, 5, 0, 1, 4, 5, 4, 1, 1, 4, 4, 5, 1, 1, 5, 4, 0, 5, 4, 4, 4, 2, 4, 1, 5, 3, 1, 3, 1, 3, 1, 5, 0, 4, 3, 4, 5, 5, 4, 4, 4, 4, 4, 0, 5, 0, 4, 4, 3, 3, 5, 5, 0, 1, 4, 1, 4, 4, 3, 1, 4, 4, 0, 4, 3, 4, 4, 5, 4, 4, 3, 1, 4, 4, 4, 0, 4, 4, 1, 4, 0, 0, 3, 5, 4, 0, 0, 4, 4, 4, 4, 5, 0, 4, 4, 4, 4, 5, 3, 1, 1, 5, 4, 1, 1, 4, 5, 1, 4, 5, 4, 1, 4, 3, 4, 4, 5, 4, 5, 1, 1, 0, 4, 0, 4, 5, 4, 4, 4, 0, 4, 3, 4, 1, 0, 3, 1, 0, 3, 0, 4, 4, 0, 4, 3, 0, 1, 5, 3, 5, 1, 4, 5, 5, 4, 4, 4, 4, 3, 5, 1, 3, 4, 3, 4, 5, 4, 4, 1, 0, 3, 4, 3, 4, 1, 4, 4, 1, 0, 4, 4, 4, 3, 3, 4, 0, 5, 1, 4, 4, 3, 1, 1, 5, 2, 0, 4, 5, 0, 4, 4, 0, 5, 5, 1, 1, 1, 5, 4, 5, 1, 1, 1, 0, 4, 4, 4, 5, 4, 4, 0, 3, 4, 4, 4, 1, 5, 0, 4, 3, 4, 5, 1, 0, 4, 4, 4, 4, 4, 0, 1, 0, 4, 4, 5, 4, 4, 3, 4, 1, 1, 4, 0, 4, 0, 3, 1, 5, 1, 4, 4, 4, 4, 4, 3, 4, 4, 1, 4, 1, 4, 4, 4, 5, 4, 4, 4, 0, 4, 4, 1, 4, 4, 0, 1, 0, 1, 5, 5, 4, 0, 2, 5, 2, 0, 4, 5, 0, 5, 1, 5, 1, 5, 1, 4, 4, 5, 4, 0, 3, 4, 1, 3, 1, 4, 4, 4, 4, 2, 0, 4, 0, 1, 4, 4, 4, 4, 5, 5, 4, 3, 5, 1, 4, 5, 1, 1, 4, 4, 4]
# label: [5, 4, 1, 4, 1, 1, 1, 1, 4, 2, 5, 4, 0, 4, 3, 5, 4, 5, 4, 5, 1, 3, 4, 4, 0, 5, 5, 4, 1, 4, 4, 4, 4, 1, 1, 1, 5, 1, 1, 1, 5, 4, 1, 1, 4, 1, 4, 0, 4, 1, 4, 1, 4, 4, 5, 4, 0, 4, 3, 3, 1, 4, 4, 4, 1, 0, 5, 1, 1, 4, 4, 1, 1, 4, 5, 3, 4, 5, 0, 4, 4, 4, 0, 4, 4, 5, 3, 5, 4, 4, 1, 3, 4, 5, 3, 0, 1, 1, 1, 3, 1, 4, 5, 4, 1, 5, 4, 4, 4, 4, 1, 4, 4, 4, 4, 1, 4, 4, 4, 1, 1, 4, 4, 4, 4, 5, 4, 4, 4, 5, 1, 4, 3, 4, 1, 3, 4, 5, 4, 4, 1, 4, 4, 4, 4, 4, 5, 3, 1, 4, 4, 4, 1, 1, 1, 4, 1, 4, 1, 4, 0, 5, 1, 1, 4, 5, 4, 1, 1, 4, 4, 5, 0, 1, 5, 4, 1, 5, 4, 4, 4, 2, 4, 1, 5, 3, 1, 1, 1, 3, 1, 4, 1, 4, 3, 4, 5, 5, 4, 4, 4, 4, 4, 1, 5, 1, 4, 4, 3, 1, 5, 5, 0, 1, 4, 1, 4, 4, 3, 1, 4, 4, 1, 4, 3, 4, 4, 4, 4, 4, 3, 1, 4, 1, 4, 1, 4, 4, 1, 4, 0, 1, 3, 5, 4, 1, 0, 4, 4, 4, 4, 5, 1, 4, 4, 4, 4, 5, 3, 1, 1, 5, 4, 1, 1, 4, 5, 1, 4, 5, 4, 1, 4, 1, 4, 4, 5, 4, 5, 1, 1, 1, 4, 1, 4, 5, 4, 4, 4, 1, 4, 3, 4, 1, 0, 3, 1, 1, 1, 1, 4, 4, 1, 4, 4, 4, 1, 0, 3, 5, 1, 4, 4, 5, 4, 4, 4, 4, 1, 5, 1, 3, 4, 3, 4, 5, 4, 4, 1, 1, 1, 4, 3, 4, 1, 4, 4, 1, 1, 4, 4, 4, 3, 1, 4, 0, 5, 1, 4, 4, 3, 0, 1, 5, 2, 2, 4, 5, 1, 4, 4, 4, 5, 5, 1, 1, 1, 5, 4, 5, 1, 1, 1, 4, 4, 4, 4, 5, 4, 4, 3, 3, 4, 4, 4, 1, 2, 1, 4, 3, 4, 5, 1, 1, 4, 4, 4, 4, 4, 2, 1, 3, 4, 4, 5, 4, 4, 3, 4, 0, 1, 4, 2, 4, 1, 3, 1, 5, 1, 4, 4, 4, 4, 4, 3, 4, 4, 0, 4, 1, 4, 4, 4, 5, 4, 4, 4, 2, 4, 4, 1, 4, 4, 5, 1, 1, 1, 5, 5, 4, 0, 2, 5, 2, 1, 4, 5, 1, 5, 1, 5, 0, 5, 1, 1, 4, 5, 4, 1, 3, 4, 1, 1, 1, 4, 4, 4, 4, 1, 1, 4, 1, 1, 4, 4, 4, 4, 5, 5, 4, 1, 5, 1, 4, 5, 1, 1, 4, 4, 4]

# %% [markdown]
# 分布を確認 (Check the distribution of data)

# %%
sdf=pd.Series(s).value_counts()
sdf.sort_index()
# Out:
# 0     70
# 1     87
# 2      8
# 3     46
# 4    215
# 5     74
# Name: count, dtype: int64

# %%
labeldf=pd.Series(label).value_counts()
labeldf.sort_index()
# Out:
# 0     21
# 1    138
# 2     10
# 3     37
# 4    223
# 5     71
# Name: count, dtype: int64

# %%
print('accuracy score: {0:0.4f}'.format(accuracy_score(label, s)))
# Out:
# accuracy score: 0.8020

# %%
print(classification_report(label, s, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.1429    0.4762    0.2198        21
#            1     0.8851    0.5580    0.6844       138
#            2     0.6250    0.5000    0.5556        10
#            3     0.6739    0.8378    0.7470        37
#            4     0.9814    0.9462    0.9635       223
#            5     0.9054    0.9437    0.9241        71
#
#     accuracy                         0.8020       500
#    macro avg     0.7023    0.7103    0.6824       500
# weighted avg     0.8789    0.8020    0.8255       500

# %%
(0.7800+0.8020)/2
# Out:
# 0.791

# %% [markdown]
# ### accuracy score
# Test data : 500
#
# - Llama3-70B : accuracy 0.886
# - Llama3-8B  : accuracy 0.780
