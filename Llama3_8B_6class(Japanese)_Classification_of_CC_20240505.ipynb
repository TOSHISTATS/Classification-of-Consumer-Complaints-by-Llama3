# %% [markdown]
# # Classification_of_Consumer_Complaints(Japanese) by Llama3-8B 20240505

# %% [markdown]
# ## 1. ライブラリをインポート (Import library)

# %%
# !pip -q install langchain-groq duckduckgo-search
# !pip -q install -U langchain_community tiktoken langchainhub
# !pip -q install -U langchain langgraph tavily-python
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 62.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.7/116.7 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.6/867.6 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 7.3 MB/s eta 0:00:00

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.1.17
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: aiohttp, async-timeout, dataclasses-json, jsonpatch, langchain-community, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
# !pip show langgraph
# Out:
# Name: langgraph
# Version: 0.0.44
# Summary: langgraph
# Home-page: https://www.github.com/langchain-ai/langgraph
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: langchain-core
# Required-by:

# %%
# !pip -q install langchain tiktoken  python-dotenv

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
os.environ["TAVILY_API_KEY"] = userdata.get('TAVILY_API_KEY')

# %%
### Tracing (optional)
import os
from pprint import pprint

# os.environ['LANGCHAIN TRACING V2'] = 'true'
# os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
# os.environ['LANGCHAIN API KEY'] = userdata.get('LANGCHAIN_API_KEY')

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.prompts import PromptTemplate

from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers import JsonOutputParser

# %% [markdown]
# ## 2. モデルをセット (Set the model throught API)

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama3-8b-8192",temperature=0)

# %%
#Categorize complaints
prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|>
    You are a Categorizer Agent You are a master at understanding what product do customers complaint of in the complaints? You can choose only one product.

     <|eot_id|><|start_header_id|>user<|end_header_id|>
    Conduct a comprehensive analysis of the complaints provided and categorize into one of the following categories:
        Mortgage\
        Checking or savings account \
        Student loan\
        Money transfer, virtual currency, or money service\
        Bank account or service\
        Consumer Loan\

            Output a single cetgory only from the types ( 'Mortgage', 'Checking or savings account', 'Student loan', 'Money transfer, virtual currency, or money service',\
       'Bank account or service', 'Consumer Loan'. Your answer should be one of the name of product in the list only. Do not include other words. \) \
            eg:
            'Mortgage' \

    EMAIL CONTENT:\n\n {email} \n\n
    <|eot_id|>
    <|start_header_id|>assistant<|end_header_id|>
    """,
    input_variables=["email"],
)

email_category_generator = prompt | model | StrOutputParser()

morg="Greetree ( changed name to Ditech servicing ) calls me all hours of the night. A representative name XXXX calls me. I told them that the only number the are allowed to contact me on is XXXX. My mother has said they also call on their number which is a separate line from my own line. Even after telling them this for months and years they still abuse this. As I have said before that the only line that I can be reach is on XXXX. I work from home and that is the only number that they can contact me regarding any information about the mortgage. I do n't know how clear I can be on discussing this with them regarding XXXX constant harassment. I am also considering legal action."

result = email_category_generator.invoke({"email": morg})

print(result)
# Out:
# Mortgage

# %%
morg
# Out:
# "Greetree ( changed name to Ditech servicing ) calls me all hours of the night. A representative name XXXX calls me. I told them that the only number the are allowed to contact me on is XXXX. My mother has said they also call on their number which is a separate line from my own line. Even after telling them this for months and years they still abuse this. As I have said before that the only line that I can be reach is on XXXX. I work from home and that is the only number that they can contact me regarding any information about the mortgage. I do n't know how clear I can be on discussing this with them regarding XXXX constant harassment. I am also considering legal action."

# %% [markdown]
# ## 3. dataをインポート (load data)

# %%
import time
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, classification_report

# %%
X=pd.read_csv("CC_20k_20230114.csv")
X
# Out:
#                             Product                                     Issue  \
# 0       Checking or savings account                       Managing an account
# 1       Checking or savings account                       Managing an account
# 2                          Mortgage            Trouble during payment process
# 3       Checking or savings account                       Managing an account
# 4                          Mortgage            Trouble during payment process
# ...                             ...                                       ...
# 199390      Bank account or service   Account opening, closing, or management
# 199391                 Student loan        Dealing with my lender or servicer
# 199392                     Mortgage  Loan modification,collection,foreclosure
# 199393                Consumer Loan                Managing the loan or lease
# 199394                     Mortgage  Loan modification,collection,foreclosure
#
#                                                      text  Complaint ID  \
# 0       XX/XX/2022. I began noticing charges to my deb...       6301154
# 1       I have a joint account with my Daughter. She g...       6280688
# 2       I made a principal payment of {$9900.00} on XX...       6257306
# 3       I created a Savings account XX/XX/2022 with Al...       6246992
# 4       Loan Number XXXX Reference : Mortgage XXXXXXXX...       6209018
# ...                                                   ...           ...
# 199390  Near the end of XXXX 2016 I opened a Citigold ...       2138969
# 199391  My loans have an extraordinarily high interest...       2302907
# 199392  Caliber Home Loans ( CHL ) sent confirmation i...       2302852
# 199393  On XX/XX/XXXX I purchased a XXXX XXXX XXXX XXX...       2282405
# 199394  My father died in XX/XX/XXXX. Left me his only...       1352738
#
#                                                        Ja
# 0       xx/xx/2022。私は自分のデビットカードへの料金とオンラインウェルズファーゴアカウント...
# 1       私は娘と共同アカウントを持っています。彼女はxxxx xxxxでxxxxに行き、私はxxxx...
# 2       xx/xx/22で{$ 9900.00}の主要な支払いを行いました。米国銀行は、XXXX X...
# 3       Ally Bankで普通預金口座XX/XX/2022を作成し、{$ 400.00}のデポジッ...
# 4       ローン番号xxxxリファレンス：Mortgage xxxxxxx xxxx xxxx xxx...
# ...                                                   ...
# 199390  XXXX 2016の終わり近くに、プロモーションコードXXXXでCitGold当座預金口座を...
# 199391             私のローンには非常に高い金利があり、私はそれらを借り換えることができません。
# 199392  キャリバーホームローン（CHL）は、2016年のXXXXで確認を送信し、ローンの変更が承認さ...
# 199393  xx/xx/xxxxでは、xxxx xxxx xxxx xxxxを購入しました。オハイオ州ド...
# 199394  父はxx/xx/xxxxで亡くなりました。私に彼の一人息子をすべて彼の持ち物に残しました、彼...
#
# [199395 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
lab = lab.fit(X["Product"])
X["label"] = lab.transform(X["Product"])
X.head()
# Out:
#                        Product                           Issue  \
# 0  Checking or savings account             Managing an account
# 1  Checking or savings account             Managing an account
# 2                     Mortgage  Trouble during payment process
# 3  Checking or savings account             Managing an account
# 4                     Mortgage  Trouble during payment process
#
#                                                 text  Complaint ID  \
# 0  XX/XX/2022. I began noticing charges to my deb...       6301154
# 1  I have a joint account with my Daughter. She g...       6280688
# 2  I made a principal payment of {$9900.00} on XX...       6257306
# 3  I created a Savings account XX/XX/2022 with Al...       6246992
# 4  Loan Number XXXX Reference : Mortgage XXXXXXXX...       6209018
#
#                                                   Ja  label
# 0  xx/xx/2022。私は自分のデビットカードへの料金とオンラインウェルズファーゴアカウント...      1
# 1  私は娘と共同アカウントを持っています。彼女はxxxx xxxxでxxxxに行き、私はxxxx...      1
# 2  xx/xx/22で{$ 9900.00}の主要な支払いを行いました。米国銀行は、XXXX X...      4
# 3  Ally Bankで普通預金口座XX/XX/2022を作成し、{$ 400.00}のデポジッ...      1
# 4  ローン番号xxxxリファレンス：Mortgage xxxxxxx xxxx xxxx xxx...      4

# %%
Xp=X[0:5000]
Xp["Product"].value_counts()
# Out:
# Product
# Checking or savings account                           2000
# Mortgage                                              1660
# Student loan                                           628
# Money transfer, virtual currency, or money service     428
# Bank account or service                                192
# Consumer Loan                                           92
# Name: count, dtype: int64

# %%
X=X[5000:]

# %%
X["Product"].value_counts()
# Out:
# Product
# Mortgage                                              88101
# Checking or savings account                           52372
# Student loan                                          26787
# Money transfer, virtual currency, or money service    13184
# Bank account or service                                9546
# Consumer Loan                                          4405
# Name: count, dtype: int64

# %%
Xt=X[["Ja"]]
Xt
# Out:
#                                                        Ja
# 5000    XXXXでは、一部の債務を統合するために、信用組合と信用枠を申請しました。彼らの検索は、私が...
# 5001    XX/XX/XXXX M＆T Bankが私に電話をかけ、私のアカウントが{$ 2000.00...
# 5002    xx/xx/xxxxでは、オンラインで時計を購入し、xxxxを使用して売り手に{$ 4500...
# 5003    タイトルはまさに述べられたとおりです。\n\nXXXXに戻ってTD銀行は、非行のために私の口...
# 5004    私はウェルズ・ファーゴとのローンを借り換えました。そもそも悪夢でしたが、最終的にXXXXで最...
# ...                                                   ...
# 199390  XXXX 2016の終わり近くに、プロモーションコードXXXXでCitGold当座預金口座を...
# 199391             私のローンには非常に高い金利があり、私はそれらを借り換えることができません。
# 199392  キャリバーホームローン（CHL）は、2016年のXXXXで確認を送信し、ローンの変更が承認さ...
# 199393  xx/xx/xxxxでは、xxxx xxxx xxxx xxxxを購入しました。オハイオ州ド...
# 199394  父はxx/xx/xxxxで亡くなりました。私に彼の一人息子をすべて彼の持ち物に残しました、彼...
#
# [194395 rows x 1 columns]

# %%
yl=X[["label"]]
yl
# Out:
#         label
# 5000        2
# 5001        1
# 5002        3
# 5003        1
# 5004        4
# ...       ...
# 199390      0
# 199391      5
# 199392      4
# 199393      2
# 199394      4
#
# [194395 rows x 1 columns]

# %%
max(yl["label"])
# Out:
# 5

# %% [markdown]
# ## 4. 訓練データと検証データを作成　(Prepare training and test data)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(Xt, yl, stratify=yl, train_size=0.013, test_size=0.013, random_state=100)
len(X_train), len(y_train), len(X_valid), len(y_valid)
# Out:
# (2527, 2527, 2528, 2528)

# %%
X_valid
# Out:
#                                                        Ja
# 85871   私は最近、xxxx xxxx xxxxからseterusに販売されました。XXXX XXXX...
# 113030  2番目の住宅ローンサービサーPlanet Home Lending Acc＃xxxxは、「そ...
# 57238   xxxx xxxxは彼女の家に住んでいる年配の女性です。彼女は必死に家を維持し、ローンを復活...
# 130633  私の住宅ローンはXXXX 2015でNationStar住宅ローンに譲渡されました。この会社...
# 26169   Ocwen Companyは、会社のさまざまな分野で指示を伝える大きな問題を抱えています。な...
# ...                                                   ...
# 159445  この苦情の理由は、このXXXXカレッジローンの利息と元本に割り当てられた金額が間違っていると...
# 157764  私たちは現在、住宅ローンで滞納しており、XXXX/XXXX/XXXXの販売日を取得しています...
# 25321   これは、この会社に対して提出された最大3つの以前の苦情です。私は12か月の返済計画を立ててい...
# 120677  私のローンサービサーであるキャンパスパートナーは、返済通知が一貫して遅刻しています。最後のx...
# 170167  xx/xx/xxxx xxxx xxxx xxxx xxxx xxxxでは、Chase Ba...
#
# [2528 rows x 1 columns]

# %%
y_valid
# Out:
#         label
# 85871       4
# 113030      4
# 57238       4
# 130633      4
# 26169       4
# ...       ...
# 159445      5
# 157764      4
# 25321       4
# 120677      5
# 170167      1
#
# [2528 rows x 1 columns]

# %%
y_valid.nunique()
# Out:
# label    6
# dtype: int64

# %%
data = pd.concat([y_valid, X_valid], axis=1)
data
# Out:
#         label                                                 Ja
# 85871       4  私は最近、xxxx xxxx xxxxからseterusに販売されました。XXXX XXXX...
# 113030      4  2番目の住宅ローンサービサーPlanet Home Lending Acc＃xxxxは、「そ...
# 57238       4  xxxx xxxxは彼女の家に住んでいる年配の女性です。彼女は必死に家を維持し、ローンを復活...
# 130633      4  私の住宅ローンはXXXX 2015でNationStar住宅ローンに譲渡されました。この会社...
# 26169       4  Ocwen Companyは、会社のさまざまな分野で指示を伝える大きな問題を抱えています。な...
# ...       ...                                                ...
# 159445      5  この苦情の理由は、このXXXXカレッジローンの利息と元本に割り当てられた金額が間違っていると...
# 157764      4  私たちは現在、住宅ローンで滞納しており、XXXX/XXXX/XXXXの販売日を取得しています...
# 25321       4  これは、この会社に対して提出された最大3つの以前の苦情です。私は12か月の返済計画を立ててい...
# 120677      5  私のローンサービサーであるキャンパスパートナーは、返済通知が一貫して遅刻しています。最後のx...
# 170167      1  xx/xx/xxxx xxxx xxxx xxxx xxxx xxxxでは、Chase Ba...
#
# [2528 rows x 2 columns]

# %% [markdown]
# ## 5. Llama3-8Bによりクレームを判別 (Classify customer complaints by Llama3-8B)

# %%
# %%time

result=[]
n=0
m=500

for i in range(n,m):

  out = email_category_generator.invoke({"email": data.iloc[i,1]})
  result.append(out)

result
# Out:
# CPU times: user 11.8 s, sys: 1.06 s, total: 12.9 s
# Wall time: 20min 21s
# ['Student loan',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  "'Mortgage'",
#  'Bank account or service',
#  'Bank account or service',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Student loan',
#  'Bank account or service',
#  "'Mortgage'",
#  'Student loan',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  "'Mortgage'",
#  'Student loan',
#  'Student loan',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  "'Mortgage'",
#  'Mortgage',
#  'Bank account or service',
#  "'Mortgage'",
#  "'Mortgage'",
#  'Bank account or service',
#  'Student loan',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Student loan',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Student loan',
#  "'Mortgage'",
#  "'Mortgage'",
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  "'Checking or savings account'",
#  'Checking or savings account',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Student loan',
#  'Student loan',
#  'Bank account or service',
#  "'Mortgage'",
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  "'Mortgage'",
#  'Student loan',
#  'Bank account or service',
#  "'Mortgage'",
#  "'Mortgage'",
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  "'Mortgage'",
#  'Mortgage',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  "'Checking or savings account'",
#  "'Mortgage'",
#  'Mortgage',
#  'Bank account or service',
#  'Checking or savings account',
#  'Bank account or service',
#  'Bank account or service',
#  "'Mortgage'",
#  'Student loan',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  "'Mortgage'",
#  "'Mortgage'",
#  'Bank account or service',
#  'Student loan',
#  "'Mortgage'",
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  "'Mortgage'",
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  "'Mortgage'",
#  'Mortgage',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Student loan',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Student loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Bank account or service',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Student loan',
#  "'Mortgage'",
#  'Bank account or service',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  'Student loan',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Bank account or service',
#  'Student loan',
#  'Student loan',
#  'Student loan',
#  'Checking or savings account',
#  'Bank account or service',
#  'Bank account or service',
#  "'Mortgage'",
#  'Bank account or service',
#  'Checking or savings account',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  'Consumer Loan',
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  'Bank account or service',
#  'Student loan',
#  'Bank account or service',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  "'Mortgage'",
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Bank account or service',
#  'Checking or savings account',
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  'Student loan',
#  'Student loan',
#  'Student loan',
#  'Student loan',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Bank account or service',
#  'Student loan',
#  "'Mortgage'",
#  'Student loan',
#  'Student loan',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Student loan',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Checking or savings account',
#  'Student loan',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Bank account or service',
#  "'Mortgage'",
#  'Student loan',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  "'Mortgage'",
#  'Student loan',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Checking or savings account',
#  'Mortgage',
#  'Mortgage',
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  'Bank account or service',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Checking or savings account',
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  "'Mortgage'",
#  "'Money transfer, virtual currency, or money service'",
#  "'Mortgage'",
#  'Bank account or service',
#  'Checking or savings account',
#  'Bank account or service',
#  "'Mortgage'",
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  "'Mortgage'",
#  'Student loan',
#  'Mortgage',
#  "'Mortgage'",
#  'Mortgage',
#  'Bank account or service',
#  'Student loan',
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  'Mortgage',
#  'Checking or savings account',
#  'Checking or savings account',
#  'Student loan',
#  'Bank account or service',
#  "'Mortgage'",
#  'Bank account or service',
#  'Mortgage',
#  'Checking or savings account',
#  'Student loan',
#  'Bank account or service',
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  'Bank account or service',
#  'Bank account or service',
#  'Student loan',
#  "'Mortgage'",
#  'Student loan',
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  'Bank account or service',
#  "'Mortgage'",
#  'Checking or savings account',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Consumer Loan',
#  'Mortgage',
#  'Checking or savings account',
#  'Student loan',
#  'Checking or savings account',
#  "'Mortgage'",
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Mortgage',
#  "'Money transfer, virtual currency, or money service'",
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Bank account or service',
#  'Bank account or service',
#  "'Money transfer, virtual currency, or money service'",
#  'Mortgage',
#  'Mortgage',
#  'Checking or savings account',
#  'Bank account or service',
#  'Student loan',
#  'Student loan',
#  'Checking or savings account',
#  'Student loan',
#  'Mortgage',
#  'Bank account or service',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Checking or savings account',
#  'Bank account or service',
#  'Student loan',
#  "'Mortgage'",
#  'Mortgage',
#  "'Mortgage'",
#  'Checking or savings account',
#  'Bank account or service',
#  'Bank account or service',
#  'Mortgage',
#  'Mortgage',
#  'Bank account or service',
#  'Bank account or service',
#  'Student loan',
#  'Checking or savings account',
#  'Mortgage',
#  'Student loan',
#  "'Mortgage'",
#  'Bank account or service']

# %%
range(n,m)
# Out:
# range(0, 500)

# %%
 list(lab.inverse_transform([0, 1, 2, 3, 4, 5]))
# Out:
# ['Bank account or service',
#  'Checking or savings account',
#  'Consumer Loan',
#  'Money transfer, virtual currency, or money service',
#  'Mortgage',
#  'Student loan']

# %%
s=result.copy()
for i in range(0,m-n):
    if "Bank account or service" in s[i]:
      s[i]=0
    elif "Checking or savings account" in s[i]:
      s[i]=1
    elif "Consumer Loan" in s[i]:
      s[i]=2
    elif "Money transfer, virtual currency, or money service" in s[i]:
      s[i]=3
    elif "Mortgage" in s[i]:
      s[i]=4
    elif "Student loan" in s[i]:
      s[i]=5
    else:
      s[i]=6
#s

# %% [markdown]
# ## 6. 精度検証　(Evaluate the model)

# %%
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x7e3619b63ee0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7e3619bb0940>, model_name='llama3-8b-8192', temperature=1e-08, groq_api_key=SecretStr('**********'))

# %%
label=list(y_valid['label'])[n:m]

print("result:", s)
print("label:", label)
# Out:
# result: [5, 4, 5, 4, 4, 0, 0, 4, 0, 4, 3, 0, 3, 1, 5, 5, 4, 4, 4, 1, 5, 0, 4, 5, 4, 4, 4, 4, 4, 4, 5, 5, 5, 0, 4, 4, 0, 4, 0, 3, 4, 4, 0, 4, 4, 0, 5, 4, 0, 4, 4, 1, 5, 4, 4, 4, 0, 5, 5, 4, 4, 0, 3, 5, 0, 0, 4, 0, 5, 4, 0, 3, 3, 0, 0, 0, 0, 1, 1, 0, 4, 4, 0, 4, 0, 4, 4, 0, 4, 0, 4, 4, 4, 4, 4, 5, 3, 4, 0, 5, 4, 4, 5, 4, 0, 4, 4, 0, 3, 4, 4, 4, 4, 4, 3, 5, 0, 4, 4, 4, 5, 5, 0, 4, 5, 3, 5, 0, 5, 3, 4, 4, 5, 0, 4, 4, 5, 1, 4, 1, 4, 4, 5, 0, 5, 4, 5, 0, 0, 3, 4, 4, 1, 4, 4, 5, 3, 1, 4, 4, 0, 1, 0, 0, 4, 5, 4, 3, 0, 0, 0, 4, 4, 3, 4, 4, 0, 5, 4, 4, 3, 5, 4, 5, 1, 4, 0, 4, 5, 0, 0, 0, 4, 4, 4, 3, 4, 0, 3, 0, 5, 4, 5, 3, 5, 5, 4, 4, 4, 4, 4, 4, 0, 4, 4, 5, 5, 4, 0, 4, 4, 0, 5, 4, 3, 0, 4, 3, 4, 3, 1, 4, 4, 4, 4, 4, 3, 4, 4, 4, 1, 0, 4, 0, 3, 0, 0, 4, 4, 5, 4, 1, 4, 5, 1, 1, 4, 3, 4, 0, 4, 1, 5, 4, 0, 5, 0, 4, 5, 4, 0, 4, 1, 4, 4, 0, 4, 5, 5, 4, 1, 0, 5, 5, 5, 1, 0, 0, 4, 0, 1, 0, 4, 4, 3, 5, 4, 4, 0, 5, 0, 4, 5, 0, 4, 2, 0, 5, 4, 0, 0, 0, 0, 4, 5, 4, 0, 4, 4, 4, 5, 4, 4, 4, 4, 0, 0, 0, 0, 5, 0, 4, 4, 4, 5, 4, 4, 3, 3, 4, 0, 1, 5, 4, 5, 5, 0, 5, 0, 5, 5, 5, 5, 5, 5, 3, 4, 4, 4, 0, 0, 5, 4, 5, 5, 4, 4, 0, 5, 4, 5, 3, 0, 4, 4, 4, 0, 5, 1, 5, 1, 1, 0, 4, 5, 4, 3, 3, 4, 4, 5, 4, 1, 1, 4, 4, 5, 0, 5, 0, 0, 3, 1, 0, 0, 4, 4, 3, 4, 0, 1, 0, 4, 5, 0, 5, 4, 5, 4, 4, 4, 0, 5, 5, 0, 5, 4, 1, 1, 5, 0, 4, 0, 4, 1, 5, 0, 5, 0, 4, 0, 0, 5, 4, 5, 0, 4, 3, 0, 4, 1, 3, 4, 2, 4, 1, 5, 1, 4, 4, 4, 0, 4, 3, 3, 4, 0, 0, 3, 4, 4, 1, 0, 5, 5, 1, 5, 4, 0, 4, 1, 1, 0, 5, 4, 4, 4, 1, 0, 0, 4, 4, 0, 0, 5, 1, 4, 5, 4, 0]
# label: [4, 4, 4, 4, 4, 4, 1, 4, 1, 4, 3, 0, 3, 1, 4, 4, 4, 4, 4, 1, 5, 1, 4, 5, 4, 4, 4, 4, 0, 4, 5, 5, 2, 1, 4, 1, 4, 4, 1, 4, 4, 4, 1, 4, 4, 1, 4, 1, 4, 4, 4, 1, 5, 4, 4, 4, 4, 5, 4, 4, 4, 1, 3, 5, 3, 1, 4, 1, 4, 4, 1, 3, 3, 1, 1, 1, 1, 1, 1, 1, 4, 4, 1, 4, 1, 4, 4, 1, 4, 1, 4, 4, 4, 4, 4, 5, 1, 4, 3, 5, 4, 4, 2, 4, 1, 1, 4, 1, 3, 4, 4, 4, 0, 4, 3, 5, 1, 4, 4, 4, 4, 5, 1, 4, 5, 3, 5, 1, 5, 3, 4, 4, 5, 1, 4, 2, 5, 1, 4, 1, 4, 4, 5, 4, 5, 4, 5, 0, 1, 0, 4, 4, 1, 4, 4, 4, 3, 0, 3, 4, 4, 1, 1, 1, 4, 5, 4, 3, 4, 3, 3, 4, 4, 3, 4, 4, 2, 4, 4, 0, 3, 5, 4, 5, 1, 4, 0, 4, 5, 3, 1, 0, 4, 4, 4, 3, 4, 0, 1, 1, 2, 4, 5, 3, 4, 5, 4, 4, 2, 4, 4, 4, 1, 4, 4, 5, 5, 4, 1, 4, 0, 1, 4, 4, 0, 1, 4, 3, 4, 4, 1, 4, 4, 4, 4, 1, 0, 4, 4, 4, 1, 1, 4, 1, 3, 5, 1, 4, 4, 5, 4, 1, 4, 2, 1, 1, 4, 3, 4, 4, 4, 1, 5, 5, 3, 5, 4, 4, 4, 4, 1, 4, 0, 4, 4, 1, 4, 4, 2, 4, 1, 4, 5, 5, 5, 1, 0, 1, 4, 1, 1, 1, 4, 4, 3, 5, 4, 4, 1, 2, 1, 4, 5, 0, 4, 2, 4, 5, 4, 4, 0, 1, 1, 4, 5, 4, 0, 4, 4, 4, 4, 4, 4, 4, 4, 1, 1, 1, 4, 5, 1, 4, 4, 4, 5, 4, 4, 3, 3, 4, 1, 1, 2, 4, 4, 5, 1, 5, 1, 5, 5, 5, 5, 5, 5, 3, 4, 4, 4, 3, 1, 5, 4, 5, 5, 4, 4, 1, 5, 4, 5, 4, 1, 4, 1, 4, 4, 2, 1, 4, 4, 1, 2, 4, 5, 4, 1, 2, 4, 4, 5, 4, 1, 5, 4, 4, 5, 4, 4, 1, 1, 0, 0, 1, 1, 4, 1, 3, 4, 1, 1, 1, 5, 5, 1, 5, 4, 4, 4, 4, 4, 1, 5, 4, 3, 5, 4, 1, 0, 5, 5, 4, 2, 4, 1, 5, 0, 4, 5, 4, 1, 4, 5, 4, 4, 1, 4, 3, 1, 4, 1, 3, 4, 2, 4, 1, 4, 1, 0, 4, 4, 1, 4, 3, 3, 4, 1, 1, 3, 4, 4, 0, 1, 4, 3, 1, 5, 4, 1, 4, 1, 1, 0, 4, 4, 4, 4, 1, 4, 1, 4, 4, 0, 1, 4, 1, 4, 4, 4, 1]

# %% [markdown]
# 分布を確認 (Check the distribution of data)

# %%
sdf=pd.Series(s).value_counts()
sdf.sort_index()
# Out:
# 0    119
# 1     41
# 2      2
# 3     39
# 4    200
# 5     99
# Name: count, dtype: int64

# %%
labeldf=pd.Series(label).value_counts()
labeldf.sort_index()
# Out:
# 0     26
# 1    119
# 2     16
# 3     38
# 4    232
# 5     69
# Name: count, dtype: int64

# %%
print('accuracy score: {0:0.4f}'.format(accuracy_score(label, s)))
# Out:
# accuracy score: 0.6460

# %%
print(classification_report(label, s, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.1008    0.4615    0.1655        26
#            1     0.8293    0.2857    0.4250       119
#            2     1.0000    0.1250    0.2222        16
#            3     0.7179    0.7368    0.7273        38
#            4     0.9200    0.7931    0.8519       232
#            5     0.6364    0.9130    0.7500        69
#
#     accuracy                         0.6460       500
#    macro avg     0.7007    0.5525    0.5236       500
# weighted avg     0.8039    0.6460    0.6709       500

# %% [markdown]
# ### accuracy score
# Test data : 500
#
# - Llama3-70B : accuracy 0.886, time 25m52s
# - Llama3-8B  : accuracy 0.778, time 19m25s

# %% [markdown]
# Test data : 500 (Japanese)
#
# - Llama3-70B : accuracy 0.828, time 46m17s
# - Llama3-8B  : accuracy 0.646, time 20m 21s
